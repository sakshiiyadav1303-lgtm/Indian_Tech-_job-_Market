# %% [markdown]
# #### Indian Tech Job Market Analysis 2026

# %% [markdown]
# ### 1. Import Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt 

plt.style.use('ggplot')
pd.set_option('display.max_columns',None)

# %% [markdown]
# ### 2. Load Dataset

# %%
df = pd.read_csv("../data/indian_tech_jobs_cleaned.csv")

# %% [markdown]
# ### 3. Dataset Overview

# %%
df.head()
# Out:
#    job_id                             job_title  \
# 0       1                        Data Scientist
# 1       2                        Data Scientist
# 2       3              Analytics Data Scientist
# 3       4                        Data Scientist
# 4       5  Sr. Artificial Intelligence Engineer
#
#                       company_name  company_rating  \
# 0                            Cisco             4.1
# 1                  Caterpillar Inc             4.1
# 2        Foreign IT Consulting MNC             3.6
# 3  Fortune 500 IT Services Company             3.6
# 4    Fortune 500 Product-based MNC             3.6
#
#                         location scraped_city   role_category experience_raw  \
# 0                      Bengaluru    Bangalore  Data Scientist       7-10 Yrs
# 1                      Bengaluru    Bangalore  Data Scientist        4-8 Yrs
# 2  Hyderabad, Chennai, Bengaluru    Bangalore  Data Scientist        4-9 Yrs
# ...

# %%
df.shape
# Out:
# (23201, 32)

# %% [markdown]
# ### 4. Dataset Information

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 23201 entries, 0 to 23200
# Data columns (total 32 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   job_id               23201 non-null  int64
#  1   job_title            23201 non-null  str
#  2   company_name         23200 non-null  str
#  3   company_rating       23201 non-null  float64
#  4   location             23201 non-null  str
#  5   scraped_city         23201 non-null  str
#  6   role_category        23201 non-null  str
#  7   experience_raw       23194 non-null  str
#  8   experience_min_yrs   23201 non-null  float64
#  9   experience_max_yrs   23201 non-null  float64
#  10  salary_raw           2771 non-null   str
#  11  salary_min_lpa       23201 non-null  float64
#  12  salary_max_lpa       23201 non-null  float64
#  13  salary_disclosed     23201 non-null  bool
#  14  skills_required      22654 non-null  str
#  15  skills_count         23201 non-null  int64
# ...

# %%
df.columns
# Out:
# Index(['job_id', 'job_title', 'company_name', 'company_rating', 'location',
#        'scraped_city', 'role_category', 'experience_raw', 'experience_min_yrs',
#        'experience_max_yrs', 'salary_raw', 'salary_min_lpa', 'salary_max_lpa',
#        'salary_disclosed', 'skills_required', 'skills_count',
#        'job_description', 'posted_date_raw', 'work_mode',
#        'company_size_bucket', 'job_url', 'data_source', 'scraped_at',
#        'salary_tier', 'experience_tier', 'is_senior', 'primary_city',
#        'skill_domain', 'salary_midpoint_lpa', 'days_since_posted',
#        'is_fresher_friendly', 'salary_negotiable'],
#       dtype='str')

# %% [markdown]
# ### 5. Statistical Summary

# %%
df.describe(include=["object", "string"])
# Out:
#             job_title               company_name   location scraped_city  \
# count           23201                      23200      23201        23201
# unique          13128                       6992       1565           11
# top     Data Engineer  Tata Consultancy Services  Bengaluru    Bangalore
# freq              847                        653       2503         3685
#
#          role_category experience_raw salary_raw  \
# count            23201          23194       2771
# unique               6            237        475
# top     Data Scientist       5-10 Yrs     Unpaid
# freq              6455           2382        306
#
#                             skills_required  \
# count                                 22654
# unique                                19184
# top     Business Analyst, Business analysis
# freq                                     53
#
#                                           job_description posted_date_raw  \
# ...

# %% [markdown]
# ### 6. Missing Values

# %%
df.isnull().sum()
# Out:
# job_id                     0
# job_title                  0
# company_name               1
# company_rating             0
# location                   0
# scraped_city               0
# role_category              0
# experience_raw             7
# experience_min_yrs         0
# experience_max_yrs         0
# salary_raw             20430
# salary_min_lpa             0
# salary_max_lpa             0
# salary_disclosed           0
# skills_required          547
# skills_count               0
# job_description          404
# posted_date_raw           49
# work_mode                  0
# company_size_bucket        0
# job_url                   53
# data_source                0
# scraped_at                 0
# salary_tier                0
# experience_tier            0
# is_senior                  0
# primary_city               0
# skill_domain               0
# salary_midpoint_lpa        0
# days_since_posted          0
# is_fresher_friendly        0
# salary_negotiable          0
# ...

# %% [markdown]
# ### 7. Duplicate Values

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.nunique()
# Out:
# job_id                 23201
# job_title              13128
# company_name            6992
# company_rating            41
# location                1565
# scraped_city              11
# role_category              6
# experience_raw           237
# experience_min_yrs        23
# experience_max_yrs        29
# salary_raw               475
# salary_min_lpa            72
# salary_max_lpa           100
# salary_disclosed           2
# skills_required        19184
# skills_count               9
# job_description        18305
# posted_date_raw           46
# work_mode                  3
# company_size_bucket        3
# job_url                21070
# data_source                1
# scraped_at                 1
# salary_tier                6
# experience_tier            5
# is_senior                  2
# primary_city             198
# skill_domain               5
# salary_midpoint_lpa      169
# days_since_posted         13
# is_fresher_friendly        2
# salary_negotiable          1
# ...

# %%
df.dtypes
# Out:
# job_id                   int64
# job_title                  str
# company_name               str
# company_rating         float64
# location                   str
# scraped_city               str
# role_category              str
# experience_raw             str
# experience_min_yrs     float64
# experience_max_yrs     float64
# salary_raw                 str
# salary_min_lpa         float64
# salary_max_lpa         float64
# salary_disclosed          bool
# skills_required            str
# skills_count             int64
# job_description            str
# posted_date_raw            str
# work_mode                  str
# company_size_bucket        str
# job_url                    str
# data_source                str
# scraped_at                 str
# salary_tier                str
# experience_tier            str
# is_senior                 bool
# primary_city               str
# skill_domain               str
# salary_midpoint_lpa    float64
# days_since_posted      float64
# ...

# %%
df.head(50)
# Out:
#     job_id                                          job_title  \
# 0        1                                     Data Scientist
# 1        2                                     Data Scientist
# 2        3                           Analytics Data Scientist
# 3        4                                     Data Scientist
# 4        5               Sr. Artificial Intelligence Engineer
# 5        6                                     Data Scientist
# 6        7                                     Data Scientist
# 7        8                            Advanced Data Scientist
# 8        9               Data Scientist, Google Play, Product
# 9       10                    Machine Learning Data Scientist
# 10      11      Sr Data Scientist - Advanced Machine Learning
# 11      12        Data Scientist - Service Parts Supply Chain
# 12      13           Data Scientist Cyber Threat Intelligence
# 13      14                                     Data Scientist
# ...

# %%
df.sample(5,random_state=42)
# Out:
#        job_id                                        job_title  \
# 259       260                                   Data Scientist
# 21183   21184                                   Deputy Manager
# 20313   20314                                Sap Po Consultant
# 8541     8542                   IoT Data Analysis Professional
# 2004     2005  Azure Data Engineer - ADF & PySpark (PAN India)
#
#                     company_name  company_rating                    location  \
# 259                    Gallagher             3.6                   Bengaluru
# 21183                Srmb Srijan             3.5                     Kolkata
# 20313  Tata Consultancy Services             3.3                       Noida
# 8541   Segula Technologies India             3.4                     Chennai
# 2004   Tata Consultancy Services             3.3  Pune, Hyderabad, Bengaluru
#
#       scraped_city     role_category experience_raw  experience_min_yrs  \
# ...

# %%
df.memory_usage(deep=True)
# Out:
# Index                      132
# job_id                  185608
# job_title               831655
# company_name            533963
# company_rating          185608
# location                577909
# scraped_city            336917
# role_category           555268
# experience_raw          364600
# experience_min_yrs      185608
# experience_max_yrs      185608
# salary_raw              222879
# salary_min_lpa          185608
# salary_max_lpa          185608
# salary_disclosed         23201
# skills_required        2552979
# skills_count            185608
# job_description        2189299
# posted_date_raw         449232
# work_mode               343515
# company_size_bucket     619297
# job_url                3079947
# data_source             417618
# scraped_at              417618
# salary_tier             457442
# experience_tier         514532
# is_senior                23201
# primary_city            341075
# skill_domain            548840
# salary_midpoint_lpa     185608
# ...

# %%
df_clean=df.copy()

# %%
df.isnull().sum()
# Out:
# job_id                     0
# job_title                  0
# company_name               1
# company_rating             0
# location                   0
# scraped_city               0
# role_category              0
# experience_raw             7
# experience_min_yrs         0
# experience_max_yrs         0
# salary_raw             20430
# salary_min_lpa             0
# salary_max_lpa             0
# salary_disclosed           0
# skills_required          547
# skills_count               0
# job_description          404
# posted_date_raw           49
# work_mode                  0
# company_size_bucket        0
# job_url                   53
# data_source                0
# scraped_at                 0
# salary_tier                0
# experience_tier            0
# is_senior                  0
# primary_city               0
# skill_domain               0
# salary_midpoint_lpa        0
# days_since_posted          0
# is_fresher_friendly        0
# salary_negotiable          0
# ...

# %%
missing_values=pd.DataFrame({
    "Missing values":df_clean.isnull().sum(),
    "Percentage":(df_clean.isnull().sum() / len(df_clean)) * 100
})

# %%
(df_clean == "Not Available").sum()
# Out:
# job_id                 0
# job_title              0
# company_name           0
# company_rating         0
# location               0
# scraped_city           0
# role_category          0
# experience_raw         0
# experience_min_yrs     0
# experience_max_yrs     0
# salary_raw             0
# salary_min_lpa         0
# salary_max_lpa         0
# salary_disclosed       0
# skills_required        0
# skills_count           0
# job_description        0
# posted_date_raw        0
# work_mode              0
# company_size_bucket    0
# job_url                0
# data_source            0
# scraped_at             0
# salary_tier            0
# experience_tier        0
# is_senior              0
# primary_city           0
# skill_domain           0
# salary_midpoint_lpa    0
# days_since_posted      0
# is_fresher_friendly    0
# salary_negotiable      0
# dtype: int64

# %%
(df_clean == "Not Available").sum()
# Out:
# job_id                 0
# job_title              0
# company_name           0
# company_rating         0
# location               0
# scraped_city           0
# role_category          0
# experience_raw         0
# experience_min_yrs     0
# experience_max_yrs     0
# salary_raw             0
# salary_min_lpa         0
# salary_max_lpa         0
# salary_disclosed       0
# skills_required        0
# skills_count           0
# job_description        0
# posted_date_raw        0
# work_mode              0
# company_size_bucket    0
# job_url                0
# data_source            0
# scraped_at             0
# salary_tier            0
# experience_tier        0
# is_senior              0
# primary_city           0
# skill_domain           0
# salary_midpoint_lpa    0
# days_since_posted      0
# is_fresher_friendly    0
# salary_negotiable      0
# dtype: int64

# %%
df_clean["work_mode"].value_counts()
# Out:
# work_mode
# On-site    18701
# Hybrid      2347
# Remote      2153
# Name: count, dtype: int64

# %%
df_clean["role_category"].value_counts()
# Out:
# role_category
# Data Scientist               6455
# Data Analyst                 4729
# Business Analyst             4505
# Machine Learning Engineer    4004
# Data Engineer                1922
# Python Developer             1586
# Name: count, dtype: int64

# %%
df_clean["experience_raw"].value_counts()
# Out:
# experience_raw
# 5-10 Yrs           2382
# 3-8 Yrs            1227
# 2-5 Yrs             918
# 4-9 Yrs             846
# 3-5 Yrs             815
#                    ...
# 19 May - 18 Jun       1
# 9-19 Yrs              1
# 16-22 Yrs             1
# 20-24 Yrs             1
# 7-16 Yrs              1
# Name: count, Length: 237, dtype: int64

# %%
df_clean["salary_raw"].value_counts().head(20)
# Out:
# salary_raw
# Unpaid           306
# 15-30 Lacs PA    142
# 10-20 Lacs PA     95
# 15-25 Lacs PA     76
# 20-35 Lacs PA     58
# 15-20 Lacs PA     46
# 10-15 Lacs PA     41
# 20-25 Lacs PA     39
# 25-40 Lacs PA     35
# 12-22 Lacs PA     32
# 25-30 Lacs PA     30
# 4-9 Lacs PA       29
# 20-30 Lacs PA     28
# 5-15 Lacs PA      28
# 5-12 Lacs PA      25
# 3-8 Lacs PA       25
# 3-6 Lacs PA       25
# 14-24 Lacs PA     25
# 8-18 Lacs PA      24
# 25-35 Lacs PA     23
# Name: count, dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df_clean["job_id"].duplicated().sum()
# Out:
# np.int64(0)

# %%
df_clean['company_rating'].describe()
# Out:
# count    23201.000000
# mean         3.586449
# std          0.514250
# min          1.000000
# 25%          3.400000
# 50%          3.600000
# 75%          3.800000
# max          5.000000
# Name: company_rating, dtype: float64

# %%
df_clean[['salary_max_lpa','salary_min_lpa']].describe()
# Out:
#        salary_max_lpa  salary_min_lpa
# count    23201.000000    23201.000000
# mean         2.271790        1.383952
# std          7.469383        4.841570
# min          0.000000        0.000000
# 25%          0.000000        0.000000
# 50%          0.000000        0.000000
# 75%          0.000000        0.000000
# max         90.000000       85.000000

# %%
df_clean[['experience_min_yrs', 'experience_max_yrs']].describe()
# Out:
#        experience_min_yrs  experience_max_yrs
# count        23201.000000        23201.000000
# mean             4.135080            7.829059
# std              2.933976            3.946834
# min              0.000000            0.000000
# 25%              2.000000            5.000000
# 50%              4.000000            8.000000
# 75%              6.000000           10.000000
# max             25.000000           31.000000

# %%
df_clean[
    df_clean["experience_min_yrs"] >
    df_clean["experience_max_yrs"]
]
# Out:
#        job_id                                          job_title  \
# 41         42  Walkin Drive | Bangalore | June 13 | Data Scie...
# 45         46                          Walk-in || Data Scientist
# 48         49  Walk-in || Data Scientist(6+ yrs exp candidate...
# 258       259  Walk-in || 13th Jun_ Data Scientist/Gen AI/MLO...
# 690       691                   Walk-in || Data Science Engineer
# ...       ...                                                ...
# 22417   22418    Walk in Interview Python Developer II Hyderabad
# 22426   22427                  Walkin Drive -Python AI developer
# 22631   22632                              ArcGIS ESRI Developer
# 23032   23033              Walk-in || Dot Net Software Developer
# 23198   23199    Walk in Interview Python Developer II Hyderabad
#
#                                 company_name  company_rating  \
# 41                 Tata Consultancy Services             3.3
# ...

# %%
df_clean[
    df_clean["salary_min_lpa"] >
    df_clean["salary_max_lpa"]
]
# Out:
# Empty DataFrame
# Columns: [job_id, job_title, company_name, company_rating, location, scraped_city, role_category, experience_raw, experience_min_yrs, experience_max_yrs, salary_raw, salary_min_lpa, salary_max_lpa, salary_disclosed, skills_required, skills_count, job_description, posted_date_raw, work_mode, company_size_bucket, job_url, data_source, scraped_at, salary_tier, experience_tier, is_senior, primary_city, skill_domain, salary_midpoint_lpa, days_since_posted, is_fresher_friendly, salary_negotiable]
# Index: []

# %%
df['salary_disclosed'].value_counts()
# Out:
# salary_disclosed
# False    20433
# True      2768
# Name: count, dtype: int64

# %%
(df['salary_disclosed'].value_counts(normalize=True)*100).round(2)
# Out:
# salary_disclosed
# False    88.07
# True     11.93
# Name: proportion, dtype: float64

# %%
df.loc[df['salary_disclosed']==False,
       ['salary_min_lpa','salary_max_lpa']]=np.nan

# %%
df[['salary_min_lpa','salary_max_lpa']].isnull().sum()
# Out:
# salary_min_lpa    20433
# salary_max_lpa    20433
# dtype: int64

# %%
df[['salary_disclosed','salary_min_lpa','salary_max_lpa']].head(15)
# Out:
#     salary_disclosed  salary_min_lpa  salary_max_lpa
# 0              False             NaN             NaN
# 1              False             NaN             NaN
# 2              False             NaN             NaN
# 3              False             NaN             NaN
# 4              False             NaN             NaN
# 5              False             NaN             NaN
# 6              False             NaN             NaN
# 7              False             NaN             NaN
# 8              False             NaN             NaN
# 9              False             NaN             NaN
# 10             False             NaN             NaN
# 11             False             NaN             NaN
# 12             False             NaN             NaN
# 13             False             NaN             NaN
# 14             False             NaN             NaN

# %%
df_clean["work_mode"].unique()
# Out:
# <ArrowStringArray>
# ['On-site', 'Hybrid', 'Remote']
# Length: 3, dtype: str

# %%
df_clean["role_category"].unique()
# Out:
# <ArrowStringArray>
# [           'Data Scientist',              'Data Analyst',
#  'Machine Learning Engineer',             'Data Engineer',
#           'Business Analyst',          'Python Developer']
# Length: 6, dtype: str

# %%
df_clean["scraped_city"].unique()
# Out:
# <ArrowStringArray>
# ['Bangalore',    'Mumbai', 'Hyderabad',      'Pune',     'Delhi',   'Chennai',
#      'Noida',   'Gurgaon',   'Kolkata', 'Ahmedabad',    'Remote']
# Length: 11, dtype: str

# %%
object_columns = df_clean.select_dtypes(include=["object", "string"]).columns

for col in object_columns:
    df_clean[col] = df_clean[col].str.strip()

# %%
df_clean.replace(
    ["Not Available", "Not Disclosed"],
    np.nan,
    inplace=True
)
# Out:
#        job_id                                        job_title  \
# 0           1                                   Data Scientist
# 1           2                                   Data Scientist
# 2           3                         Analytics Data Scientist
# 3           4                                   Data Scientist
# 4           5             Sr. Artificial Intelligence Engineer
# ...       ...                                              ...
# 23196   23197                       Python Developer-Hyderabad
# 23197   23198                                 Python Developer
# 23198   23199  Walk in Interview Python Developer II Hyderabad
# 23199   23200                                 Python Developer
# 23200   23201                                 Python Developer
#
#                           company_name  company_rating  \
# 0                                Cisco             4.1
# 1                      Caterpillar Inc             4.1
# ...

# %%
df["experience_tier"].unique()
# Out:
# <ArrowStringArray>
# [       'Senior (6-8 Yrs)',           'Mid (3-5 Yrs)',
#                  'Fresher',        'Junior (0-2 Yrs)',
#  'Lead/Architect (9+ Yrs)']
# Length: 5, dtype: str

# %%
df["salary_tier"].unique()
# Out:
# <ArrowStringArray>
# [         'Undisclosed',   'Senior (10-20 LPA)', 'Leadership (20+ LPA)',
#        'Mid (6-10 LPA)',     'Junior (3-6 LPA)',       'Entry (<3 LPA)']
# Length: 6, dtype: str

# %%
df["work_mode"].unique()
# Out:
# <ArrowStringArray>
# ['On-site', 'Hybrid', 'Remote']
# Length: 3, dtype: str

# %%
df_clean.to_csv("indian_tech_jobs_cleaned.csv", index=False)
